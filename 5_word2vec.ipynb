# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'term', 'a', 'originated', 'as', 'term', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.689804
# Nearest to about: kee, graves, bahrain, diameters, endorsed, pounder, drops, plaintiffs,
# Nearest to most: slightest, penicillin, grim, uphold, complicate, waitress, faa, thrives,
# Nearest to between: antiparticles, senussi, soundhole, quartz, topol, anacondas, dassault, hamza,
# Nearest to during: deliveries, withers, conical, draugr, freyja, implicitly, facilities, nano,
# Nearest to and: phrase, hua, industrialisation, nucleosynthesis, arctocephalus, nafta, urgell, overviews,
# Nearest to after: satirizing, mencken, hplc, kerberos, regulate, lancer, impurity, euskal,
# Nearest to these: conses, antipodes, felonies, kipsigis, chaitin, stirner, butler, spinoff,
# Nearest to s: glycemic, pedestrian, azhar, psp, summers, fencing, interdependent, laban,
# Nearest to of: http, listener, camped, ovaries, antiparticle, rivest, unsecured, astros,
# Nearest to however: pang, yea, bewitched, talks, violinist, divinities, constellation, transcription,
# Nearest to its: henceforth, syst, fb, rebuke, malthusian, unleavened, trek, protectionism,
# Nearest to time: feist, fabian, tunable, hermon, consonant, coat, assistants, parsley,
# Nearest to people: resident, jamming, lawfully, diglossia, momentarily, dobb, helen, reuse,
# Nearest to d: unfavourably, portillo, climate, disciplines, regime, kickapoo, holomorphic, aldiss,
# Nearest to this: paladin, myelin, diagonally, portfolio, tana, terracotta, beau, poetry,
# Nearest to if: lucien, issuer, flue, elegy, silk, fiorentina, extending, circuit,
# Average loss at step 2000: 4.365561
# Average loss at step 4000: 3.859860
# Average loss at step 6000: 3.796011
# Average loss at step 8000: 3.688636
# Average loss at step 10000: 3.616106
# Nearest to about: yoko, drops, protozoa, crocodiles, tumour, kee, bahrain, celts,
# Nearest to most: grim, past, unifil, slightest, more, aoc, penicillin, waitress,
# Nearest to between: soundhole, anacondas, locksmiths, topol, senussi, antiparticles, cutoff, pontiff,
# Nearest to during: before, at, in, after, fresnel, deliveries, yoruba, tarn,
# Nearest to and: or, s, d, phrase, lamborghini, of, altars, own,
# Nearest to after: before, during, climbing, daewoo, mencken, in, crude, satirizing,
# Nearest to these: partly, biblioth, institut, many, reflux, felonies, expropriation, graze,
# Nearest to s: his, and, laban, rounds, logistic, spotty, jeffery, provisioning,
# Nearest to of: in, same, lough, and, outfits, for, wark, thrust,
# Nearest to however: portugal, hauer, prized, medica, acquiesced, installation, marcellus, marathon,
# Nearest to its: the, his, their, amongst, some, trek, lesund, her,
# Nearest to time: consonant, although, fabian, freshness, hansard, redesign, bahn, grid,
# Nearest to people: resident, annotation, momentarily, piedmont, baroque, steadman, lawfully, contrary,
# Nearest to d: b, and, jana, racecar, unfavourably, holomorphic, curls, braxton,
# Nearest to this: it, the, lehmann, which, a, their, scuttled, nassau,
# Nearest to if: could, sloped, mmm, climactic, acids, abigail, flue, landsmannschaft,
# Average loss at step 12000: 3.607039
# Average loss at step 14000: 3.569484
# Average loss at step 16000: 3.409632
# Average loss at step 18000: 3.464926
# Average loss at step 20000: 3.542930
# Nearest to about: tumour, additionally, over, drops, protozoa, reelected, kee, celts,
# Nearest to most: more, grim, unifil, past, some, property, apology, anarchism,
# Nearest to between: with, from, soundhole, in, anacondas, pontiff, antiparticles, through,
# Nearest to during: at, after, in, before, over, lexical, wrist, millar,
# Nearest to and: or, but, in, which, kantian, skills, with, favored,
# Nearest to after: before, during, when, affectation, climbing, daewoo, giving, satirizing,
# Nearest to these: some, many, several, they, all, biblioth, which, relics,
# Nearest to s: replies, petsamo, laban, whitbread, taxable, punks, rounds, sumatran,
# Nearest to of: lough, for, genetic, in, melchior, same, lith, cosmo,
# Nearest to however: but, that, medica, and, among, prized, acquiesced, hauer,
# Nearest to its: their, his, the, her, amongst, some, this, lesund,
# Nearest to time: consonant, hansard, bahn, freshness, year, years, lambasted, devoured,
# Nearest to people: resident, annotation, students, hannity, steadman, veterinarian, galliard, astrometry,
# Nearest to d: b, unfavourably, jana, racecar, galba, deist, anderson, holomorphic,
# Nearest to this: it, which, scuttled, the, their, its, often, lehmann,
# Nearest to if: could, climactic, but, since, where, annunzio, mules, when,
# Average loss at step 22000: 3.504022
# Average loss at step 24000: 3.490915
# Average loss at step 26000: 3.482701
# Average loss at step 28000: 3.481996
# Average loss at step 30000: 3.506137
# Nearest to about: tumour, over, drops, additionally, saeed, protozoa, reelected, cossiga,
# Nearest to most: more, past, grim, some, unifil, many, property, apology,
# Nearest to between: with, from, in, soundhole, on, anacondas, plucked, inversions,
# Nearest to during: after, in, before, at, from, on, yoruba, of,
# Nearest to and: or, but, however, in, own, including, of, s,
# Nearest to after: before, during, when, climbing, in, from, daewoo, affectation,
# Nearest to these: some, many, several, all, are, they, such, other,
# Nearest to s: his, whitbread, ordinated, spotty, shogun, laban, and, whose,
# Nearest to of: including, in, for, outfits, from, genetic, and, analogs,
# Nearest to however: but, when, although, and, while, which, where, if,
# Nearest to its: their, his, the, her, amongst, our, arabized, lesund,
# Nearest to time: year, consonant, lambasted, bahn, redesignated, hansard, hailing, amount,
# Nearest to people: resident, students, steadman, veterinarian, astrometry, annotation, galliard, correcting,
# Nearest to d: b, unfavourably, anderson, jana, racecar, deist, neapolitan, meatball,
# Nearest to this: it, which, what, scuttled, any, that, blur, routinely,
# Nearest to if: when, could, but, where, sloped, that, though, climactic,
# Average loss at step 32000: 3.504899
# Average loss at step 34000: 3.492395
# Average loss at step 36000: 3.460066
# Average loss at step 38000: 3.302174
# Average loss at step 40000: 3.432331
# Nearest to about: drops, protozoa, tumour, on, additionally, over, speed, fatima,
# Nearest to most: more, less, past, grim, some, slightest, lightsaber, shorts,
# Nearest to between: with, through, from, inversions, anacondas, soundhole, antiparticles, on,
# Nearest to during: after, at, before, in, until, on, yoruba, succeeding,
# Nearest to and: or, but, image, in, including, like, however, e,
# Nearest to after: before, during, when, through, climbing, affectation, hplc, zil,
# Nearest to these: some, many, several, all, both, such, they, those,
# Nearest to s: his, claire, interpretative, steals, sumatran, daunting, laban, subclasses,
# Nearest to of: in, for, macaulay, from, outfits, caters, lough, cosmo,
# Nearest to however: but, although, that, while, though, which, possess, century,
# Nearest to its: their, his, the, her, any, extensive, hx, lesund,
# Nearest to time: year, years, consonant, bahn, lambasted, way, period, industrially,
# Nearest to people: students, resident, australasia, person, astrometry, annotation, steadman, alle,
# Nearest to d: b, unfavourably, panavia, jana, anderson, UNK, deist, rau,
# Nearest to this: which, it, the, any, that, outraged, some, a,
# Nearest to if: when, could, where, flue, sloped, that, icing, derwent,
# Average loss at step 42000: 3.436295
# Average loss at step 44000: 3.453840
# Average loss at step 46000: 3.453893
# Average loss at step 48000: 3.354548
# Average loss at step 50000: 3.382604
# Nearest to about: on, monomorphism, drops, around, mazes, tumour, imports, speed,
# Nearest to most: more, less, some, many, past, unifil, lightsaber, use,
# Nearest to between: with, through, from, anacondas, in, inversions, antiparticles, among,
# Nearest to during: after, in, at, before, from, within, throughout, of,
# Nearest to and: or, but, of, while, including, in, however, s,
# Nearest to after: before, when, during, through, despite, climbing, giving, zil,
# Nearest to these: some, many, both, several, such, all, those, usually,
# Nearest to s: shaanxi, sumatran, whitbread, and, laban, attending, interpretative, subclasses,
# Nearest to of: in, and, lough, during, from, caters, rm, fps,
# Nearest to however: but, although, that, while, though, when, which, where,
# Nearest to its: their, his, the, her, our, extensive, teil, migraine,
# Nearest to time: year, way, period, amount, consonant, place, revolutionized, industrially,
# Nearest to people: resident, students, galliard, person, tunku, floated, astrometry, players,
# Nearest to d: b, unfavourably, panavia, rau, jana, anderson, f, riffing,
# Nearest to this: which, it, the, outraged, that, some, animism, novelization,
# Nearest to if: when, where, though, could, derwent, flue, so, surges,
# Average loss at step 52000: 3.436867
# Average loss at step 54000: 3.424896
# Average loss at step 56000: 3.437447
# Average loss at step 58000: 3.399407
# Average loss at step 60000: 3.392755
# Nearest to about: around, monomorphism, tumour, imports, additionally, on, holborn, protozoa,
# Nearest to most: more, some, many, past, less, use, unifil, thirteen,
# Nearest to between: with, through, inversions, within, among, from, in, antiparticles,
# Nearest to during: after, before, following, in, at, until, within, throughout,
# Nearest to and: or, but, than, including, themed, environmentally, although, carotene,
# Nearest to after: before, during, when, despite, through, beyond, throughout, while,
# Nearest to these: some, many, several, all, those, such, both, they,
# Nearest to s: ordinated, laban, whose, punks, geddes, calvinist, claire, subclasses,
# Nearest to of: outfits, in, lough, like, for, boredom, main, tawhid,
# Nearest to however: but, although, though, which, that, when, while, there,
# Nearest to its: their, his, the, her, our, extensive, arabized, gilda,
# Nearest to time: year, way, period, place, fun, advantage, breastplate, amount,
# Nearest to people: students, historians, scholars, others, galliard, resident, alle, person,
# Nearest to d: b, panavia, h, jana, c, unfavourably, siding, anderson,
# Nearest to this: which, it, the, what, there, outraged, that, some,
# Nearest to if: when, where, though, could, because, so, then, without,
# Average loss at step 62000: 3.242417
# Average loss at step 64000: 3.253535
# Average loss at step 66000: 3.402680
# Average loss at step 68000: 3.398064
# Average loss at step 70000: 3.355895
# Nearest to about: around, over, monomorphism, on, protozoa, between, dionysius, imports,
# Nearest to most: more, less, many, some, use, thirteen, unifil, all,
# Nearest to between: with, within, among, inversions, in, from, through, into,
# Nearest to during: after, before, following, in, until, throughout, since, within,
# Nearest to and: or, but, like, including, while, see, using, of,
# Nearest to after: before, during, when, despite, while, through, without, beyond,
# Nearest to these: some, such, many, several, are, all, those, their,
# Nearest to s: whose, claire, stepmother, petsamo, must, laban, ordinated, gotha,
# Nearest to of: including, in, include, and, cappella, like, heft, combatant,
# Nearest to however: but, although, though, when, that, while, where, which,
# Nearest to its: their, his, the, her, our, tsarevich, hemi, any,
# Nearest to time: place, year, period, advantage, way, redesignated, consonant, controversy,
# Nearest to people: students, men, scholars, historians, others, americans, person, members,
# Nearest to d: b, panavia, unfavourably, h, siding, jana, anderson, kickapoo,
# Nearest to this: which, it, that, the, what, itself, outraged, some,
# Nearest to if: when, where, though, although, while, could, before, for,
# Average loss at step 72000: 3.380695
# Average loss at step 74000: 3.351658
# Average loss at step 76000: 3.324299
# Average loss at step 78000: 3.355777
# Average loss at step 80000: 3.382989
# Nearest to about: around, imports, monomorphism, over, protozoa, dionysius, home, mazes,
# Nearest to most: more, some, many, less, unifil, backbone, slightest, among,
# Nearest to between: within, among, with, inversions, in, through, from, concerning,
# Nearest to during: after, before, in, following, until, throughout, when, within,
# Nearest to and: or, while, including, than, but, malign, amiable, although,
# Nearest to after: before, during, when, despite, while, without, through, until,
# Nearest to these: several, many, those, some, both, various, such, they,
# Nearest to s: claire, laban, arundel, sumatran, unfiltered, tte, nelson, wegener,
# Nearest to of: lough, including, in, herein, although, during, knocking, entire,
# Nearest to however: although, but, that, though, while, including, when, teri,
# Nearest to its: their, his, her, the, our, hemi, whose, ghidorah,
# Nearest to time: year, standardize, advantage, place, way, cedes, period, krav,
# Nearest to people: men, students, scholars, historians, children, jews, words, person,
# Nearest to d: b, unfavourably, h, siding, f, jana, panavia, des,
# Nearest to this: which, it, the, another, nassau, that, what, each,
# Nearest to if: when, though, where, before, since, after, without, although,
# Average loss at step 82000: 3.405621
# Average loss at step 84000: 3.409867
# Average loss at step 86000: 3.393665
# Average loss at step 88000: 3.355473
# Average loss at step 90000: 3.365950
# Nearest to about: around, mazes, monomorphism, over, imports, protozoa, tasked, least,
# Nearest to most: more, less, some, many, unifil, slightest, especially, practiced,
# Nearest to between: with, inversions, within, among, from, through, concerning, into,
# Nearest to during: after, in, before, until, following, under, throughout, within,
# Nearest to and: or, but, while, including, however, geocaching, reloading, wilderness,
# Nearest to after: before, during, when, despite, while, without, until, through,
# Nearest to these: several, some, many, those, are, such, all, both,
# Nearest to s: ordinated, whose, claire, his, her, whitbread, isbn, my,
# Nearest to of: including, for, in, heighten, philly, include, cappella, following,
# Nearest to however: but, although, though, that, while, cases, since, including,
# Nearest to its: their, his, her, the, our, whose, gaudy, ghidorah,
# Nearest to time: year, period, way, place, generically, maximilian, standardize, redesignated,
# Nearest to people: students, men, person, members, scholars, historians, alle, players,
# Nearest to d: b, unfavourably, panavia, siding, h, jana, f, c,
# Nearest to this: it, which, some, the, another, itself, any, each,
# Nearest to if: when, though, where, before, since, after, without, atalh,
# Average loss at step 92000: 3.397551
# Average loss at step 94000: 3.254231
# Average loss at step 96000: 3.361061
# Average loss at step 98000: 3.243273
# Average loss at step 100000: 3.354593
# Nearest to about: around, on, monomorphism, dionysius, least, imports, mazes, over,
# Nearest to most: more, less, especially, many, past, lightsaber, some, very,
# Nearest to between: among, inversions, with, within, through, across, anacondas, antiparticles,
# Nearest to during: in, after, before, following, throughout, until, within, at,
# Nearest to and: or, but, while, although, however, including, when, of,
# Nearest to after: before, when, during, without, despite, through, while, though,
# Nearest to these: several, some, many, those, all, certain, weezer, instead,
# Nearest to s: whose, his, exeter, claire, whitbread, my, mallarm, bowels,
# Nearest to of: including, in, during, entire, wark, adolph, and, distorted,
# Nearest to however: but, although, that, though, while, especially, and, which,
# Nearest to its: their, his, the, her, our, whose, lesund, extensive,
# Nearest to time: year, way, amount, thing, place, conjecture, period, standardize,
# Nearest to people: students, men, players, person, alle, members, americans, children,
# Nearest to d: b, c, te, sampo, cummins, emanuel, h, bodyguard,
# Nearest to this: it, which, what, another, itself, he, that, some,
# Nearest to if: when, where, though, before, for, while, then, natchez,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# The architecture of the neural network used to train CBOW is shown in below figure. CBOW uses the same weight for every word in the context window and sums up the results in the hidden layer neurons.

# %% [markdown]
# <img src = 'CBOW.png'>

# %% [markdown]
# Function to generate a training batch for the CBOW model.

# %%
from itertools import islice

# %%
data_index = 0

def generate_batch(batch_size, context_window):
  global data_index
  batch = np.ndarray(shape=(batch_size, 2 * context_window), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * context_window + 1 # [ context_window target context_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    target = context_window  # target label at the center of the buffer
    labels[i, 0] = buffer[target]
    batch[i] = list(islice(buffer, 0, target)) + list(islice(buffer, target+1, len(buffer)))
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:12]])

for context_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, context_window=context_window)
    print('\nwith context_window = %d:' % context_window)
    print('    batch:', [[reverse_dictionary[bi] for bi in b] for b in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working']
#
# with context_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with context_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# Train a CBOW model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
context_window = 2 # How many context words left and right to use for prediction of target word.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2 * context_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embed, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(batch_size, context_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.608329
# Nearest to most: embezzlement, sabbath, erd, lionel, tying, cams, urge, christi,
# Nearest to and: discipleship, maccabean, eritrean, capp, fathers, pressburg, irv, bahamian,
# Nearest to may: gniezno, baudelaire, definition, regis, projector, woodbridge, when, chartres,
# Nearest to first: tribesmen, octopussy, fd, revealed, carrel, kang, hokku, mercalli,
# Nearest to one: adenosine, limbic, ponce, sicilies, antonym, riesz, campaigner, castrati,
# Nearest to see: celtics, overpowered, auckland, handfasting, informers, potato, scholarship, dramatic,
# Nearest to while: forza, seymour, finite, mcg, belize, devised, denison, uppsala,
# Nearest to such: alla, syria, erasing, nrc, fevers, putatively, vortex, disconcerting,
# Nearest to will: metrodome, fits, galen, erlk, cohabitation, unequalled, bridges, thomson,
# Nearest to an: tagore, koenig, dies, colspan, khmelnytsky, squares, consequently, guinness,
# Nearest to eight: kilobit, ima, siegfried, raison, jotham, blah, darmstadt, forgiven,
# Nearest to is: protected, klingon, tangier, irwin, dido, progression, beam, laetrile,
# Nearest to years: soybean, leq, dojo, access, factories, compl, entries, intact,
# Nearest to american: cloak, noticed, unsympathetic, intestines, dione, storms, microwave, glottalized,
# Nearest to other: deke, kleist, perfume, proline, obsidian, accreditation, tampa, lollards,
# Nearest to war: decoy, negotiator, regents, homeopathy, help, telomerase, surplus, microscopy,
# Average loss at step 2000: 4.597805
# Average loss at step 4000: 3.934265
# Average loss at step 6000: 3.731771
# Average loss at step 8000: 3.528132
# Average loss at step 10000: 3.474566
# Nearest to most: more, many, bmx, some, morricone, coating, cryo, radiology,
# Nearest to and: or, for, like, slovaks, dicotyledons, ehr, mckellen, burbank,
# Nearest to may: can, would, could, should, will, must, might, to,
# Nearest to first: same, rational, overloaded, second, escalating, ksc, thatcherism, castles,
# Nearest to one: identifier, two, email, internment, zeroes, saudi, predate, melvins,
# Nearest to see: regulate, unrelated, nest, conceptually, dorian, lumbar, celtics, handfasting,
# Nearest to while: spinster, apcs, synchronicity, greeting, roadways, lz, companions, persecute,
# Nearest to such: well, known, operations, carboniferous, alla, uwe, maxima, bluebeard,
# Nearest to will: would, can, could, may, cannot, must, should, to,
# Nearest to an: a, any, the, borrowers, koenig, slovakian, istrian, chargaff,
# Nearest to eight: nine, six, seven, four, three, five, zero, michinaga,
# Nearest to is: was, are, became, has, inferred, hasan, were, microchip,
# Nearest to years: soybean, sleeper, rebelling, therapist, myst, year, gladius, time,
# Nearest to american: elbridge, holley, british, lieu, scullin, french, statuette, nik,
# Nearest to other: these, many, tampa, more, several, different, sting, various,
# Nearest to war: radiotelephone, bullet, sanctus, hues, diminutive, colour, pup, negotiator,
# Average loss at step 12000: 3.488914
# Average loss at step 14000: 3.435153
# Average loss at step 16000: 3.431087
# Average loss at step 18000: 3.386507
# Average loss at step 20000: 3.221088
# Nearest to most: more, very, some, cryo, many, coating, ppm, less,
# Nearest to and: or, but, while, dicotyledons, adenauer, by, including, zach,
# Nearest to may: can, would, will, must, should, could, might, cannot,
# Nearest to first: last, second, next, escalating, overloaded, same, tleilax, minus,
# Nearest to one: uploads, totaled, narcotics, clowns, hoping, lactate, collaborators, condon,
# Nearest to see: fractures, bern, called, numeration, grimm, glencoe, expire, bavarian,
# Nearest to while: when, although, if, but, crioulo, and, like, where,
# Nearest to such: well, regarded, known, blackhawks, described, karlheinz, negotiator, carboniferous,
# Nearest to will: would, can, may, could, must, should, might, did,
# Nearest to an: another, the, any, cameras, a, crests, this, borrowers,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to is: was, are, became, were, makes, has, inferred, suggests,
# Nearest to years: days, months, decades, waveform, rebelling, year, representatives, esquire,
# Nearest to american: british, dutch, pairs, vectorborne, solf, political, empress, babe,
# Nearest to other: different, various, these, more, caliber, newsstand, heywood, vertebra,
# Nearest to war: mould, radiotelephone, negotiator, transclusion, diminutive, angular, bullet, wars,
# Average loss at step 22000: 3.361174
# Average loss at step 24000: 3.291193
# Average loss at step 26000: 3.260495
# Average loss at step 28000: 3.284293
# Average loss at step 30000: 3.225308
# Nearest to most: many, some, more, cryo, very, coating, ppm, reminder,
# Nearest to and: while, although, including, but, or, however, like, zach,
# Nearest to may: can, would, must, might, should, could, will, cannot,
# Nearest to first: last, second, next, same, original, final, before, escalating,
# Nearest to one: magistrates, two, vieira, microprocessors, sejm, automotive, wax, symbolize,
# Nearest to see: numeration, but, called, estimator, expire, specialty, ravine, anarcha,
# Nearest to while: and, although, when, however, like, because, after, where,
# Nearest to such: well, regarded, known, described, beginnings, unreadable, result, blackhawks,
# Nearest to will: would, could, can, must, may, should, might, did,
# Nearest to an: this, another, the, fashioned, mills, a, saviola, furor,
# Nearest to eight: nine, six, seven, five, four, zero, three, rorty,
# Nearest to is: was, are, became, makes, has, remains, were, includes,
# Nearest to years: days, months, decades, year, esquire, weeks, hours, intermarriage,
# Nearest to american: america, arab, dutch, yourself, amg, pickford, british, australian,
# Nearest to other: various, different, those, ellsworth, these, withdrawals, palestrina, dispensationalism,
# Nearest to war: wars, negotiator, telomerase, pastoral, mould, diminutive, decoy, speciality,
# Average loss at step 32000: 3.008659
# Average loss at step 34000: 3.202279
# Average loss at step 36000: 3.193842
# Average loss at step 38000: 3.155815
# Average loss at step 40000: 3.158477
# Nearest to most: more, less, many, some, goren, highly, rampage, largest,
# Nearest to and: or, while, but, including, although, than, cleves, ict,
# Nearest to may: can, could, should, might, must, will, would, cannot,
# Nearest to first: last, second, next, same, final, third, best, original,
# Nearest to one: four, this, inductive, six, chinook, mendelevium, qualitative, swanson,
# Nearest to see: estimator, known, includes, enlisting, numeration, dorian, but, swings,
# Nearest to while: and, although, however, but, or, than, among, where,
# Nearest to such: well, regarded, follows, opposed, seen, far, result, described,
# Nearest to will: would, could, may, can, should, might, must, cannot,
# Nearest to an: another, puppets, fashioned, blameless, argentines, furor, the, swordsmen,
# Nearest to eight: seven, six, nine, five, four, three, zero, two,
# Nearest to is: was, are, remains, became, has, were, being, includes,
# Nearest to years: decades, months, days, year, weeks, hours, times, esquire,
# Nearest to american: america, national, british, amg, australian, montague, contractions, mlm,
# Nearest to other: various, some, different, earlier, agnostics, outpouring, those, these,
# Nearest to war: wars, negotiator, aeroflot, lecture, overhauled, advisable, sensitivities, teat,
# Average loss at step 42000: 3.205478
# Average loss at step 44000: 3.135876
# Average loss at step 46000: 3.141639
# Average loss at step 48000: 3.063586
# Average loss at step 50000: 3.058448
# Nearest to most: more, some, less, many, especially, cryo, redneck, goren,
# Nearest to and: or, but, while, although, including, quantization, lderlin, omnipotence,
# Nearest to may: can, should, could, might, must, will, would, cannot,
# Nearest to first: last, next, second, final, original, latter, best, same,
# Nearest to one: switzerland, seven, conscription, paused, four, eusebio, addition, aggadah,
# Nearest to see: includes, known, expire, include, estimator, ravine, contains, numeration,
# Nearest to while: although, when, where, however, and, among, before, if,
# Nearest to such: well, follows, described, regarded, seen, opposed, known, result,
# Nearest to will: would, could, should, might, must, can, may, cannot,
# Nearest to an: another, the, kerman, furor, evade, swordsmen, synonyms, stephenson,
# Nearest to eight: nine, seven, six, five, four, three, zero, liebig,
# Nearest to is: was, are, makes, became, remains, becomes, contains, includes,
# Nearest to years: days, months, decades, weeks, year, hours, times, esquire,
# Nearest to american: british, canadian, australian, bernardi, eller, pickford, cuzco, national,
# Nearest to other: various, different, rather, pathophysiology, these, additional, earlier, including,
# Nearest to war: wars, teat, runways, negotiator, overhauled, angular, diminutive, sensitivities,
# Average loss at step 52000: 3.095641
# Average loss at step 54000: 3.086222
# Average loss at step 56000: 2.926961
# Average loss at step 58000: 3.023732
# Average loss at step 60000: 3.043949
# Nearest to most: some, more, particularly, many, cryo, earliest, last, especially,
# Nearest to and: while, but, although, or, than, including, however, nor,
# Nearest to may: can, could, might, should, must, will, would, cannot,
# Nearest to first: last, second, next, third, final, best, original, latter,
# Nearest to one: two, four, troppo, lauter, chinook, lingered, mistletoe, mandola,
# Nearest to see: includes, known, numeration, include, contains, but, flea, bogside,
# Nearest to while: although, and, where, though, when, however, because, before,
# Nearest to such: well, follows, regarded, opposed, described, seen, result, served,
# Nearest to will: would, could, might, must, should, can, may, cannot,
# Nearest to an: another, a, the, furor, no, istrian, noord, codd,
# Nearest to eight: nine, seven, five, six, four, three, zero, two,
# Nearest to is: was, are, remains, became, makes, includes, has, becomes,
# Nearest to years: months, days, decades, weeks, hours, times, centuries, year,
# Nearest to american: america, australian, british, canadian, arab, elbridge, sobre, amg,
# Nearest to other: various, rather, those, agnostics, cb, starfish, individual, either,
# Nearest to war: wars, feast, angular, teat, pilgrims, inhumane, diminutive, negotiator,
# Average loss at step 62000: 3.015465
# Average loss at step 64000: 2.917312
# Average loss at step 66000: 2.936828
# Average loss at step 68000: 2.962359
# Average loss at step 70000: 3.011141
# Nearest to most: more, especially, earliest, particularly, some, less, many, last,
# Nearest to and: or, but, while, including, although, marienburg, applescript, caesarion,
# Nearest to may: might, can, could, should, will, would, must, cannot,
# Nearest to first: last, second, next, third, final, best, latter, earliest,
# Nearest to one: troppo, recoveries, nic, madhuri, stovl, anglophone, hif, stuttgart,
# Nearest to see: includes, numeration, saw, known, allows, usp, expire, conceptually,
# Nearest to while: and, although, when, however, than, behind, though, or,
# Nearest to such: well, described, follows, opposed, known, regarded, seen, served,
# Nearest to will: would, should, must, could, might, can, may, cannot,
# Nearest to an: another, any, furor, istrian, the, stephenson, argentines, kaolinite,
# Nearest to eight: nine, seven, six, five, zero, three, two, f,
# Nearest to is: was, are, makes, remains, becomes, includes, provides, has,
# Nearest to years: decades, months, days, year, weeks, minutes, hours, centuries,
# Nearest to american: british, australian, canadian, english, america, elbridge, boldness, baseball,
# Nearest to other: various, rather, older, different, multiple, those, sketchy, these,
# Nearest to war: wars, diminutive, championships, baroque, hues, conflict, teat, sensitivities,
# Average loss at step 72000: 2.941521
# Average loss at step 74000: 2.864201
# Average loss at step 76000: 2.996823
# Average loss at step 78000: 3.004723
# Average loss at step 80000: 2.847925
# Nearest to most: more, less, some, many, earliest, particularly, cryo, highly,
# Nearest to and: or, including, etc, but, mem, though, like, nor,
# Nearest to may: might, can, could, should, will, cannot, would, must,
# Nearest to first: last, next, second, best, third, earliest, latter, oldest,
# Nearest to one: resulting, two, troppo, aggadah, supercomputers, proficient, interplanetary, ribosomes,
# Nearest to see: but, numeration, includes, cosine, saw, airliners, ningen, contains,
# Nearest to while: although, however, though, where, jock, after, among, when,
# Nearest to such: well, follows, opposed, served, described, regarded, far, known,
# Nearest to will: would, could, might, must, should, can, may, cannot,
# Nearest to an: another, cetacean, furor, argentines, esaf, kyo, evade, istrian,
# Nearest to eight: nine, seven, six, five, three, four, zero, two,
# Nearest to is: was, makes, are, becomes, provides, remains, became, contains,
# Nearest to years: decades, months, days, year, weeks, minutes, hours, centuries,
# Nearest to american: america, australian, canadian, italian, british, rukh, sobre, boldness,
# Nearest to other: various, different, both, earlier, admixture, individual, additional, rather,
# Nearest to war: wars, diminutive, inhumane, decoy, baroque, sensitivities, hues, teat,
# Average loss at step 82000: 2.939670
# Average loss at step 84000: 2.905487
# Average loss at step 86000: 2.930529
# Average loss at step 88000: 2.943544
# Average loss at step 90000: 2.835138
# Nearest to most: some, more, many, especially, less, cryo, earliest, highly,
# Nearest to and: or, but, while, although, though, nor, including, etc,
# Nearest to may: might, could, can, will, should, would, must, cannot,
# Nearest to first: last, best, second, next, final, earliest, greatest, original,
# Nearest to one: seven, two, nine, resulting, four, six, rth, assists,
# Nearest to see: includes, numeration, contains, but, zfc, allows, guthrie, yam,
# Nearest to while: although, and, though, unlike, when, or, tiled, where,
# Nearest to such: well, follows, seen, known, opposed, regarded, result, far,
# Nearest to will: would, might, could, should, must, can, may, cannot,
# Nearest to an: another, the, any, furor, evade, cetacean, istrian, a,
# Nearest to eight: seven, six, nine, four, three, five, zero, two,
# Nearest to is: was, are, remains, makes, becomes, provides, has, requires,
# Nearest to years: decades, months, days, centuries, hours, year, weeks, minutes,
# Nearest to american: america, australian, canadian, british, indian, lieu, contraceptives, irish,
# Nearest to other: various, different, others, multiple, both, aquarium, agnostics, pathophysiology,
# Nearest to war: wars, conflict, diminutive, inhumane, feast, intuitions, sensitivities, sited,
# Average loss at step 92000: 2.899955
# Average loss at step 94000: 2.887468
# Average loss at step 96000: 2.719865
# Average loss at step 98000: 2.454096
# Average loss at step 100000: 2.702971
# Nearest to most: particularly, more, especially, less, best, some, last, highly,
# Nearest to and: but, or, while, etc, ozarks, like, though, including,
# Nearest to may: might, can, could, should, must, would, will, cannot,
# Nearest to first: last, next, second, best, third, only, earliest, final,
# Nearest to one: resulting, camps, mandola, rth, lingered, newsstand, bec, turn,
# Nearest to see: references, includes, known, include, allows, contains, called, apply,
# Nearest to while: however, although, when, but, and, where, though, argue,
# Nearest to such: well, follows, result, seen, regarded, opposed, far, classified,
# Nearest to will: would, should, could, must, might, can, may, cannot,
# Nearest to an: another, furor, d, cetacean, contraception, argentines, any, evade,
# Nearest to eight: seven, six, nine, five, four, three, zero, two,
# Nearest to is: was, remains, are, makes, provides, represents, exists, has,
# Nearest to years: decades, months, days, year, hours, weeks, centuries, minutes,
# Nearest to american: canadian, australian, english, british, irish, french, scottish, swedish,
# Nearest to other: various, different, others, both, multiple, earlier, several, agnostics,
# Nearest to war: wars, conflict, sited, superconductors, runways, responsa, speciality, compositional,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
